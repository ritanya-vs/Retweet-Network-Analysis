# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## **JUSTIN BIEBER**

# %%
justin=pd.read_csv('justinbieber_with_timestamp.csv')

jedges = justin[['Node1', 'Node2']].values.tolist()


jgraph = nx.from_edgelist(jedges)


nx.draw_networkx(jgraph,nx.spring_layout(jgraph),with_labels=False)
plt.show()

# %% [markdown]
# The graph helps to understand the overall structure and connections between users involved in retweeting hashtags related to Justin Bieber.

# %%
jn=jgraph.number_of_nodes()
je=jgraph.number_of_edges()
jd=jgraph.degree()
print('Number of nodes : ',jn)
print('Number of edges : ',je)
print('Degree of nodes : ',jd)
# Out:
# Number of nodes :  9405
# Number of edges :  9584
# ...

# %% [markdown]
# In this network, node 722 has the highest degree, with 3,875 connections, indicating that it plays a central role in the network .
# This high degree suggests significant connectivity,serving as a major hub in information spread within the dataset.

# %%
jdc = nx.degree_centrality(jgraph)
top_jdc = sorted(jdc.items(), key=lambda item: item[1], reverse=True)[:10]
df_jdc = pd.DataFrame(top_jdc, columns=['Node', 'Degree Centrality'])
print("Top 10 Nodes by Degree Centrality:")
print(df_jdc)
# Out:
# Top 10 Nodes by Degree Centrality:
#    Node  Degree Centrality
# 0   722           0.412059
# 1   314           0.354317
# 2  7227           0.143769
# 3   468           0.057848
# 4  3549           0.008082
# 5  8284           0.004679
# 6  4746           0.002658
# 7  4384           0.002552
# 8  9264           0.002552
# 9  4742           0.002127

# %% [markdown]
# The top 10 nodes by degree centrality highlight node 722 as the most central, with a degree centrality of 0.412, indicating it has a substantial influence within the network. Node 314 follows closely with a degree centrality of 0.354, suggesting it also holds significant connectivity.

# %%
bottom_jdc = sorted(jdc.items(), key=lambda item: item[1])[:10]
df_bottom_jdc = pd.DataFrame(bottom_jdc, columns=['Node', 'Degree Centrality'])
print("Bottom 10 Nodes by Degree Centrality:")
print(df_bottom_jdc)
# Out:
# Bottom 10 Nodes by Degree Centrality:
#    Node  Degree Centrality
# 0   746           0.000106
# 1  2851           0.000106
# 2  8371           0.000106
# 3  8297           0.000106
# 4  3933           0.000106
# 5  9166           0.000106
# 6  6548           0.000106
# 7  4209           0.000106
# 8  8219           0.000106
# 9  8603           0.000106

# %% [markdown]
# These are the bottom 10 nodes based on degree centrality.

# %%
jcc = nx.closeness_centrality(jgraph)
top_jcc = sorted(jcc.items(), key=lambda item: item[1], reverse=True)[:10]
df_jcc = pd.DataFrame(top_jcc, columns=['Node', 'Closeness Centrality'])
print("\nTop 10 Nodes by Closeness Centrality:")
print(df_jcc)
# Out:
# Top 10 Nodes by Closeness Centrality:
#    Node  Closeness Centrality
# 0   722              0.457282
# 1  8308              0.423623
# 2   314              0.423070
# 3   449              0.403935
# 4  6215              0.403380
# 5  1676              0.403380
# 6    23              0.403380
# 7  8095              0.403380
# 8  7440              0.403380
# 9  6261              0.403380

# %% [markdown]
# Node 722 has the highest closeness centrality at 0.457, indicating it lies closer to most of nodes in the network , making it an efficient node for spreading information across the network.

# %%
bottom_jcc = sorted(jcc.items(), key=lambda item: item[1])[:10]
df_bottom_jcc = pd.DataFrame(bottom_jcc, columns=['Node', 'Closeness Centrality'])
print("Bottom 10 Nodes by Closeness Centrality:")
print(df_bottom_jcc)
# Out:
# Bottom 10 Nodes by Closeness Centrality:
#    Node  Closeness Centrality
# 0  7453              0.145514
# 1  4787              0.145514
# 2  4517              0.145514
# 3  1420              0.145514
# 4  6161              0.145514
# 5  5452              0.145514
# 6  9033              0.145514
# 7  4240              0.145514
# 8  3991              0.145514
# 9  5785              0.145514

# %% [markdown]
# These are the bottom 10 nodes based on closeness centrality.

# %%
jbc = nx.betweenness_centrality(jgraph)
top_jbc = sorted(jbc.items(), key=lambda item: item[1], reverse=True)[:10]
df_jbc = pd.DataFrame(top_jbc, columns=['Node', 'Betweenness Centrality'])
print("\nTop 10 Nodes by Betweenness Centrality:")
print(df_jbc)
# Out:
# Top 10 Nodes by Betweenness Centrality:
#    Node  Betweenness Centrality
# 0   722                0.675724
# 1   314                0.580577
# 2  7227                0.264925
# 3   468                0.110681
# 4  3549                0.019289
# 5  8284                0.018410
# 6  8308                0.014705
# 7   449                0.013634
# 8  5178                0.012645
# 9  2783                0.012645

# %% [markdown]
# Node 722 has the highest betweenness centrality at 0.675, indicating it lies in most of the shortest path in the network.

# %%
bottom_jbc = sorted(jbc.items(), key=lambda item: item[1])[:10]
df_bottom_jbc = pd.DataFrame(bottom_jbc, columns=['Node', 'Betweenness Centrality'])
print("\nBottom 10 Nodes by Betweenness Centrality:")
print(df_bottom_jbc)
# Out:
# Bottom 10 Nodes by Betweenness Centrality:
#    Node  Betweenness Centrality
# 0   746                     0.0
# 1  2851                     0.0
# 2  8371                     0.0
# 3  8297                     0.0
# 4  3933                     0.0
# 5  9166                     0.0
# 6  6548                     0.0
# 7  4209                     0.0
# 8  8219                     0.0
# 9  8603                     0.0

# %% [markdown]
# These are the bottom 10 nodes based on betweenness centrality.

# %%
jec = nx.eigenvector_centrality(jgraph,max_iter=1000, tol=1e-06)
top_jec = sorted(jec.items(), key=lambda item: item[1], reverse=True)[:10]
df_jec = pd.DataFrame(top_jec, columns=['Node', 'Eigenvector Centrality'])
print("\nTop 10 Nodes by Eigenvector Centrality:")
print(df_jec)
# Out:
# Top 10 Nodes by Eigenvector Centrality:
#    Node  Eigenvector Centrality
# 0   722                0.705713
# 1   314                0.039199
# 2  7227                0.017202
# 3  8308                0.012036
# 4   449                0.011967
# 5  6215                0.011963
# 6  1676                0.011963
# 7    23                0.011963
# 8  8095                0.011963
# 9  7440                0.011963

# %% [markdown]
# Node 722 is highest influential node.

# %% [markdown]
# On applying node centrality measures to the network graph of Justin Bieber's hashtag retweet network its understood that node 722 is the most influential node (i.e) the user most capable of spreading information by means of retweets

# %%
bottom_jec = sorted(jec.items(), key=lambda item: item[1])[:10]
df_bottom_jec = pd.DataFrame(bottom_jec, columns=['Node', 'Eigenvector Centrality'])
print("\nBottom 10 Nodes by Eigenvector Centrality:")
print(df_bottom_jec)
# Out:
# Bottom 10 Nodes by Eigenvector Centrality:
#    Node  Eigenvector Centrality
# 0  2773            1.169888e-09
# 1  7453            1.551188e-09
# 2  4787            1.551188e-09
# 3  4517            1.551188e-09
# 4  1420            1.551188e-09
# 5  6161            1.551188e-09
# 6  5452            1.551188e-09
# 7  9033            1.551188e-09
# 8  4240            1.551188e-09
# 9  3991            1.551188e-09

# %% [markdown]
# These are the bottom 10 nodes based on eigen vector centrality.

# %%
unique_nodes = [722, 314, 7227, 468, 3549, 8284, 4746, 4384, 9264, 4742,
                8308, 449, 6215, 1676, 23, 8095, 7440, 6261, 5178, 2783]


edge_list = [(u, v) for u, v in jgraph.edges(unique_nodes) if u in unique_nodes and v in unique_nodes]



degree_centrality = nx.degree_centrality(jgraph)
closeness_centrality = nx.closeness_centrality(jgraph)
betweenness_centrality = nx.betweenness_centrality(jgraph)
eigenvector_centrality = nx.eigenvector_centrality(jgraph, max_iter=1000, tol=1e-06)

centrality_measures = pd.DataFrame({
    "Node": unique_nodes,
    "Degree Centrality": [degree_centrality.get(node, 0) for node in unique_nodes],
    "Closeness Centrality": [closeness_centrality.get(node, 0) for node in unique_nodes],
    "Betweenness Centrality": [betweenness_centrality.get(node, 0) for node in unique_nodes],
    "Eigenvector Centrality": [eigenvector_centrality.get(node, 0) for node in unique_nodes]
})

print("Centrality Measures for the Nodes:\n", centrality_measures)
centrality_measures['Rank'] = centrality_measures['Eigenvector Centrality'].rank(ascending=False)
sorted_centrality = centrality_measures.sort_values(by='Eigenvector Centrality', ascending=False)
print("Based on Eigen Vector Centrality:\n",
      sorted_centrality[['Node', 'Eigenvector Centrality', 'Rank']])
# Out:
# Centrality Measures for the Nodes:
#      Node  Degree Centrality  Closeness Centrality  Betweenness Centrality  \
# 0    722           0.412059              0.457282                0.675724
# 1    314           0.354317              0.423070                0.580577
# 2   7227           0.143769              0.364298                0.264925
# 3    468           0.057848              0.340799                0.110681
# 4   3549           0.008082              0.267585                0.019289
# 5   8284           0.004679              0.348154                0.018410
# 6   4746           0.002658              0.333251                0.004666
# 7   4384           0.002552              0.216817                0.004674
# 8   9264           0.002552              0.170291                0.004681
# 9   4742           0.002127              0.174555                0.003612
# 10  8308           0.000319              0.423623                0.014705
# ...

# %% [markdown]
# ## **ONE DIRECTION**

# %%
one=pd.read_csv('onedirection_with_timestamp.csv')

oedges = one[['Node1', 'Node2']].values.tolist()


ograph = nx.from_edgelist(oedges)


nx.draw_networkx(ograph,nx.spring_layout(ograph),with_labels=False)
plt.show()

# %%
on=ograph.number_of_nodes()
oe=ograph.number_of_edges()
od=ograph.degree()
print('Number of nodes : ',on)
print('Number of edges : ',oe)
print('Degree of nodes : ',od)
# Out:
# Number of nodes :  7987
# Number of edges :  8103
# ...

# %% [markdown]
# In this network, node 4097 has the highest degree, with 23 connections, indicating that it plays a central role in the network .
# This high degree suggests significant connectivity,serving as a major hub in information spread within the dataset.

# %%
odc = nx.degree_centrality(ograph)
top_odc = sorted(odc.items(), key=lambda item: item[1], reverse=True)[:10]
df_odc = pd.DataFrame(top_odc, columns=['Node', 'Degree Centrality'])
print("Top 10 Nodes by Degree Centrality:")
print(df_odc)
# Out:
# Top 10 Nodes by Degree Centrality:
#    Node  Degree Centrality
# 0  4977           0.746431
# 1  1121           0.112447
# 2  2235           0.022289
# 3  3206           0.021037
# 4  7689           0.009141
# 5  3811           0.008891
# 6  5343           0.008390
# 7   275           0.008139
# 8  2347           0.006386
# 9  6734           0.006261

# %% [markdown]
# The top 10 nodes by degree centrality highlight node 4977 as the most central, with a degree centrality of 0.746, indicating it has a substantial influence within the network. Node 1121 follows closely with a degree centrality of 0.112, suggesting it also holds significant connectivity.

# %%
bottom_odc = sorted(odc.items(), key=lambda item: item[1])[:10]
df_bottom_odc = pd.DataFrame(bottom_odc, columns=['Node', 'Degree Centrality'])
print("Bottom 10 Nodes by Degree Centrality:")
print(df_bottom_odc)
# Out:
# Bottom 10 Nodes by Degree Centrality:
#    Node  Degree Centrality
# 0  2332           0.000125
# 1  5332           0.000125
# 2  4652           0.000125
# 3  4909           0.000125
# 4  6403           0.000125
# 5  4523           0.000125
# 6  3019           0.000125
# 7  4379           0.000125
# 8  3976           0.000125
# 9  4111           0.000125

# %%
occ = nx.closeness_centrality(ograph)
top_occ = sorted(occ.items(), key=lambda item: item[1], reverse=True)[:10]
df_occ = pd.DataFrame(top_occ, columns=['Node', 'Closeness Centrality'])
print("\nTop 10 Nodes by Closeness Centrality:")
print(df_occ)
# Out:
# Top 10 Nodes by Closeness Centrality:
#    Node  Closeness Centrality
# 0  4977              0.663234
# 1  7457              0.441289
# 2   661              0.438141
# 3  6062              0.438093
# 4  1532              0.438093
# 5  5692              0.438093
# 6  6038              0.438093
# 7  2724              0.438093
# 8  4017              0.438093
# 9  4525              0.438093

# %% [markdown]
# Node 4977 has the highest closeness centrality at 0.663, indicating it lies closer to most of nodes in the network , making it an efficient node for spreading information across the network.

# %%
bottom_occ = sorted(occ.items(), key=lambda item: item[1])[:10]
df_bottom_occ = pd.DataFrame(bottom_occ, columns=['Node', 'Closeness Centrality'])
print("Bottom 10 Nodes by Closeness Centrality:")
print(df_bottom_occ)
# Out:
# Bottom 10 Nodes by Closeness Centrality:
#    Node  Closeness Centrality
# 0  1733              0.134334
# 1  3329              0.134334
# 2  6955              0.136271
# 3  4118              0.136271
# 4  1469              0.136271
# 5  1029              0.136271
# 6   290              0.136271
# 7  3842              0.154039
# 8  2250              0.154039
# 9  4726              0.154039

# %%
obc = nx.betweenness_centrality(ograph)
top_obc = sorted(obc.items(), key=lambda item: item[1], reverse=True)[:10]
df_obc = pd.DataFrame(top_obc, columns=['Node', 'Betweenness Centrality'])
print("\nTop 10 Nodes by Betweenness Centrality:")
print(df_obc)
# Out:
# Top 10 Nodes by Betweenness Centrality:
#    Node  Betweenness Centrality
# 0  4977                0.965796
# 1  1121                0.212652
# 2  2235                0.042799
# 3  3206                0.041354
# 4  2347                0.028279
# 5   275                0.018901
# 6  7689                0.017233
# 7  3811                0.016041
# 8  5343                0.015525
# 9  1180                0.014842

# %% [markdown]
# Node 4977 has the highest betweenness centrality at 0.96, indicating it lies in most of the shortest path in the network.

# %%
bottom_obc = sorted(obc.items(), key=lambda item: item[1])[:10]
df_bottom_obc = pd.DataFrame(bottom_obc, columns=['Node', 'Betweenness Centrality'])
print("\nBottom 10 Nodes by Betweenness Centrality:")
print(df_bottom_obc)
# Out:
# Bottom 10 Nodes by Betweenness Centrality:
#    Node  Betweenness Centrality
# 0  2332                     0.0
# 1  5332                     0.0
# 2  4652                     0.0
# 3  4909                     0.0
# 4  6403                     0.0
# 5  4523                     0.0
# 6  3019                     0.0
# 7  4379                     0.0
# 8  3976                     0.0
# 9  4111                     0.0

# %%
oec = nx.eigenvector_centrality(ograph,max_iter=1000,tol=1e-6)
top_oec = sorted(oec.items(), key=lambda item: item[1], reverse=True)[:10]
df_oec = pd.DataFrame(top_oec, columns=['Node', 'Eigenvector Centrality'])
print("\nTop 10 Nodes by Eigenvector Centrality:")
print(df_oec)
# Out:
# Top 10 Nodes by Eigenvector Centrality:
#    Node  Eigenvector Centrality
# 0  4977                0.707131
# 1  2347                0.010318
# 2  5702                0.009536
# 3  4981                0.009300
# 4  5504                0.009297
# 5    91                0.009292
# 6  4147                0.009291
# 7  7588                0.009291
# 8  1931                0.009291
# 9  7842                0.009291

# %% [markdown]
# Node 4977 is highest influential node.

# %%
bottom_oec = sorted(oec.items(), key=lambda item: item[1])[:10]
df_bottom_oec = pd.DataFrame(bottom_oec, columns=['Node', 'Eigenvector Centrality'])
print("\nBottom 10 Nodes by Eigenvector Centrality:")
print(df_bottom_oec)
# Out:
# Bottom 10 Nodes by Eigenvector Centrality:
#    Node  Eigenvector Centrality
# 0  1733            3.363416e-12
# 1  3329            3.363416e-12
# 2  6955            7.432677e-11
# 3  4118            7.432677e-11
# 4  1469            7.432677e-11
# 5  1029            7.432677e-11
# 6   290            7.432677e-11
# 7  3842            2.584762e-10
# 8  2250            2.584762e-10
# 9  4726            2.584762e-10

# %%
unique_nodes = [4977, 1121, 2235, 3206, 7689, 3811, 5343, 275, 2347, 6734, 7457, 661, 6062, 1532, 5692, 6038, 2724, 4017, 4525, 1180, 5702, 4981, 5504, 91, 4147, 7588, 1931, 7842]


edge_list = [(u, v) for u, v in ograph.edges(unique_nodes) if u in unique_nodes and v in unique_nodes]

degree_centrality = nx.degree_centrality(ograph)
closeness_centrality = nx.closeness_centrality(ograph)
betweenness_centrality = nx.betweenness_centrality(ograph)
eigenvector_centrality = nx.eigenvector_centrality(ograph, max_iter=1000, tol=1e-06)

centrality_measures = pd.DataFrame({
    "Node": unique_nodes,
    "Degree Centrality": [degree_centrality.get(node, 0) for node in unique_nodes],
    "Closeness Centrality": [closeness_centrality.get(node, 0) for node in unique_nodes],
    "Betweenness Centrality": [betweenness_centrality.get(node, 0) for node in unique_nodes],
    "Eigenvector Centrality": [eigenvector_centrality.get(node, 0) for node in unique_nodes]
})

print("Centrality Measures for the Nodes:\n", centrality_measures)
centrality_measures['Rank'] = centrality_measures['Eigenvector Centrality'].rank(ascending=False)
sorted_centrality = centrality_measures.sort_values(by='Eigenvector Centrality', ascending=False)
print("Based on Eigen Vector Centrality:\n",
      sorted_centrality[['Node', 'Eigenvector Centrality', 'Rank']])
# Out:
# Centrality Measures for the Nodes:
#      Node  Degree Centrality  Closeness Centrality  Betweenness Centrality  \
# 0   4977           0.746431              0.663234                0.965796
# 1   1121           0.112447              0.342086                0.212652
# 2   2235           0.022289              0.314781                0.042799
# 3   3206           0.021037              0.318828                0.041354
# 4   7689           0.009141              0.307983                0.017233
# 5   3811           0.008891              0.316102                0.016041
# 6   5343           0.008390              0.292753                0.015525
# 7    275           0.008139              0.295668                0.018901
# 8   2347           0.006386              0.413183                0.028279
# 9   6734           0.006261              0.289757                0.012192
# 10  7457           0.000376              0.441289                0.011224
# ...

# %% [markdown]
# On applying node centrality measures to the network graph of One Direction's hashtag retweet network its understood that node 4977 is the most influential node (i.e) the user most capable of spreading information by means of retweets

# %%
# Function for temporal analysis of retweet networks grouped by week
def temporal_analysis_by_week(df, title):
    # Check if the DataFrame is empty
    if df.empty:
        print("The DataFrame is empty. Cannot perform temporal analysis.")
        return

    # Convert timestamp to datetime format
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
    df['year_week'] = df['Timestamp'].dt.to_period('W')  # Group by year and week

    # Group data by each week
    weekly_groups = df.groupby('year_week')

    # Determine grid size based on the number of weeks
    num_weeks = len(weekly_groups)
    if num_weeks == 0:
        print("No data available for weekly analysis.")
        return

    num_cols = 3
    num_rows = (num_weeks // num_cols) + (num_weeks % num_cols > 0)

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))
    fig.suptitle(title, fontsize=16)

    # Flatten axes array for easy iteration, even if it's a single row
    axes = axes.flatten() if num_weeks > 1 else [axes]

    # Iterate over each week and create a subplot
    for i, (week, group) in enumerate(weekly_groups):
        ax = axes[i]

        # Create a graph for each week's data
        G_week = nx.from_pandas_edgelist(group, 'Node1', 'Node2', create_using=nx.Graph())

        # Get position for all nodes in the weekly network
        pos = nx.spring_layout(G_week)

        # Draw network on the subplot
        nx.draw_networkx_nodes(G_week, pos, ax=ax, node_size=50, node_color='blue', alpha=0.7)
        nx.draw_networkx_edges(G_week, pos, ax=ax, edge_color='gray', alpha=0.5)
        ax.set_title(f'Week: {week}', fontsize=12)
        ax.axis('off')

    # Hide any unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.subplots_adjust(top=0.9)  # Adjust to make space for the main title
    plt.show()

# %%
# Apply temporal analysis by week to both datasets
print("Temporal Analysis for Justin Bieber Network (by week):")
temporal_analysis_by_week(justin, "Justin Bieber Network (Weekly Analysis)")
# Out:
# Temporal Analysis for Justin Bieber Network (by week):

# %% [markdown]
# For Justin Bieber dataset , in the initial week a larger community is invloved in retweeting , in the further weeks we can see there are more retweets in smaller communities.

# %%
print("Temporal Analysis for One Direction Network (by week):")
temporal_analysis_by_week(one, "One Direction Network (Weekly Analysis)")
# Out:
# Temporal Analysis for One Direction Network (by week):

# %% [markdown]
# For One Direction dataset , in the initial week a larger community is invloved in retweeting , in the further weeks we can see there are more retweets in smaller communities.

# %%
def analyze_information_spread(df):
    # Convert timestamp to datetime format
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
    df['year_week'] = df['Timestamp'].dt.to_period('W')

    # Group data by each week
    weekly_groups = df.groupby('year_week')

    # Store metrics for analysis
    spread_metrics = []

    # Iterate over each week
    for week, group in weekly_groups:
        # Create the graph for the week
        G_week = nx.from_pandas_edgelist(group, 'Node1', 'Node2', create_using=nx.DiGraph())

        # Calculate network metrics
        num_nodes = G_week.number_of_nodes()
        num_edges = G_week.number_of_edges()
        largest_component_size = len(max(nx.weakly_connected_components(G_week), key=len))
        avg_clustering_coefficient = nx.average_clustering(G_week.to_undirected())

        # Measure centrality metrics to identify key influencers
        centrality = nx.degree_centrality(G_week)
        max_centrality = max(centrality.values()) if centrality else 0

        # Store metrics for the week
        spread_metrics.append({
            'Week': str(week),
            'Num_Nodes': num_nodes,
            'Num_Edges': num_edges,
            'Largest_Component_Size': largest_component_size,
            'Avg_Clustering_Coefficient': avg_clustering_coefficient,
            'Max_Centrality': max_centrality
        })

    # Convert metrics to DataFrame for further analysis
    metrics_df = pd.DataFrame(spread_metrics)
    print(metrics_df)

    # Plot some key metrics over time
    plt.figure(figsize=(12, 6))
    plt.plot(metrics_df['Week'], metrics_df['Num_Nodes'], label='Number of Nodes', marker='o')
    plt.plot(metrics_df['Week'], metrics_df['Num_Edges'], label='Number of Edges', marker='s')
    plt.plot(metrics_df['Week'], metrics_df['Largest_Component_Size'], label='Largest Component Size', marker='^')
    plt.xticks(rotation=45)
    plt.xlabel('Week')
    plt.ylabel('Metric Value')
    plt.title('Weekly Information Spread Metrics')
    plt.legend()
    plt.tight_layout()
    plt.show()

    return metrics_df

# %%
# Analyze information spread in the network
metrics_df = analyze_information_spread(justin)
# Out:
#                     Week  Num_Nodes  Num_Edges  Largest_Component_Size  \
# 0  2012-09-03/2012-09-09       5151       5230                    5122
# 1  2012-09-10/2012-09-16       4311       4331                    4272
# 2  2012-09-17/2012-09-23         63         54                      23
#
#    Avg_Clustering_Coefficient  Max_Centrality
# 0                    0.001452        0.715146
# 1                    0.000084        0.773550
# 2                    0.000000        0.338710

# %% [markdown]
# The network is large, with 5,151 nodes and 5,230 edges, and the largest component includes nearly all nodes (5,122), suggesting a well-connected network that can facilitate broad information spread. The average clustering coefficient is low (0.001452), indicating minimal local clustering, or "grouping," among nodes. Despite this, the high max centrality (0.715) suggests that a few highly connected nodes act as major hubs, driving network-wide connectivity and effective information dissemination.

# %% [markdown]
# In Weeks 1 and 2, the network is large and well-connected, with highly central nodes that enable effective information spread despite low local clustering. By Week 3, the network becomes highly fragmented, with only a few connected nodes, no central hubs, and no clustering, greatly reducing its ability to facilitate widespread information dissemination.

# %%
# Analyze information spread in the network
metrics_df = analyze_information_spread(one)
# Out:
#                     Week  Num_Nodes  Num_Edges  Largest_Component_Size  \
# 0  2012-08-27/2012-09-02       1721       1707                    1609
# 1  2012-09-03/2012-09-09       2251       2264                    2140
# 2  2012-09-10/2012-09-16       3796       3790                    3742
# 3  2012-09-17/2012-09-23        379        372                     364
#
#    Avg_Clustering_Coefficient  Max_Centrality
# 0                    0.000000        0.700000
# 1                    0.001672        0.379111
# 2                    0.000000        0.970487
# 3                    0.000000        0.960317

# %% [markdown]
# In the first three weeks, the network expands considerably, with a peak in Week 3 showing high connectivity (3,796 nodes, 3,790 edges) and a max centrality of 0.970, indicating a highly influential node facilitating information spread. Clustering remains extremely low, showing minimal localized groups. In Week 4, the network shrinks significantly (379 nodes, 372 edges) with no clustering and a high max centrality of 0.960, suggesting that while the network is smaller, it still has one central node that can connect most of the network.

# %%
def calculate_diffusion_speed(df, target_users):
    # Convert timestamp to datetime
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
    df = df.sort_values('Timestamp')  # Sort by time to track diffusion

    # Track unique users over time
    unique_users = set()
    time_to_reach = []

    for i, row in df.iterrows():
        unique_users.add(row['Node2'])  # Assuming 'Node2' is the user who retweeted
        if len(unique_users) >= target_users:
            # Record the time it took to reach the target number of users
            time_to_reach.append(row['Timestamp'])
            break

    if time_to_reach:
        # Calculate the time difference
        start_time = df['Timestamp'].min()
        time_taken = (time_to_reach[0] - start_time).total_seconds() / 3600  # Convert to hours
        print(f"Time to reach {target_users} users: {time_taken:.2f} hours")
    else:
        print(f"Did not reach {target_users} users within the data.")

def calculate_information_flow_rate(df, time_interval='1H'):
    # Convert timestamp to datetime and sort
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
    df = df.sort_values('Timestamp')

    # Group by specified time interval
    retweets_per_interval = df.groupby(pd.Grouper(key='Timestamp', freq=time_interval)).size()

    # Plot the information flow rate
    plt.figure(figsize=(12, 6))
    retweets_per_interval.plot(kind='line', marker='o', label='Retweets per Interval')
    plt.xlabel('Time')
    plt.ylabel('Number of Retweets')
    plt.title('Information Flow Rate Over Time')
    plt.legend()
    plt.tight_layout()
    plt.show()

    return retweets_per_interval

# %%
# Calculate diffusion speed for reaching 100 users
calculate_diffusion_speed(justin, target_users=100)

# Calculate and plot information flow rate (retweets per hour)
flow_rate = calculate_information_flow_rate(justin, time_interval='1h')
# Out:
# Time to reach 100 users: 20.77 hours

# %% [markdown]
# Given that it takes about 20.77 hours to reach 100 users, the information flow rate can be calculated as the number of users gained per hour. This indicates how quickly information is spreading through the network.

# %%
# Calculate diffusion speed for reaching 100 users
calculate_diffusion_speed(one, target_users=100)

# Calculate and plot information flow rate (retweets per hour)
flow_rate = calculate_information_flow_rate(one, time_interval='1h')
# Out:
# Time to reach 100 users: 0.62 hours

# %% [markdown]
# Given that it takes about 0.62 hours to reach 100 users, the information flow rate can be calculated as the number of users gained per hour. This indicates how quickly information is spreading through the network.
